# %% [markdown]
# ->Task: Descriptive Analysis
#
# ->Calculate basic statistical measures (mean,
#   median, standard deviation, etc.) for numerical
#   columns.
#
# ->Explore the distribution of categorical
#   variables like "Country Code,
#
#   " "City,
#
#   " and"
#
#  "Cuisines"
#
#
# ->Identify the top cuisines and cities with the
#   highest number of restaurants.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13112\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r'c:\Users\Dell\Downloads\Dataset .csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
x=df['Latitude']

# %%
mean=x.mean()
mode=x.mode()
mediian=x.median()
std=x.std()
print('Latitude mean is',mean)
print('Latitude mode is',mode)
print('Latitude median is',mediian)
print('Std of latitude is ',std)
# Out:
# Latitude mean is 25.854380700074756
# Latitude mode is 0    0.0
# Name: Latitude, dtype: float64
# Latitude median is 28.57046888
# Std of latitude is  11.007935124784668

# %%
y=df['Longitude']
mean=y.mean()
mode=y.mode()
median=y.median()
std=y.std()
print('Mean of Longitude is ',mean)
print('Mode of Longitude is ',mode)
print('Median of Longitude is', median)
print('Std of Longitude is ',std)
# Out:
# Mean of Longitude is  64.12657446168706
# Mode of Longitude is  0    0.0
# Name: Longitude, dtype: float64
# Median of Longitude is 77.1919642
# Std of Longitude is  41.46705784761728

# %%
c=df['Price range']
mean=c.mean()
mode=c.mode()
median=c.median()
std=c.std()
print('Mean of Price Range is ',mean)
print('Mode of Price Range is ',mode)
print('Median of Price Range is', median)
print('Std of Price Range is ',std)
# Out:
# Mean of Price Range is  1.804837189823055
# Mode of Price Range is  0    1
# Name: Price range, dtype: int64
# Median of Price Range is 2.0
# Std of Price Range is  0.905608847397614

# %%
b=df['Aggregate rating']
mean=b.mean()
mode=b.mode()
median=b.median()
std=b.std()
print('Mean of Aggregate rating is ',mean)
print('Mode of Aggregate rating is ',mode)
print('Median of Aggregate rating is', median)
print('Std of Aggregate rating is ',std)
# Out:
# Mean of Aggregate rating is  2.66637001361114
# Mode of Aggregate rating is  0    0.0
# Name: Aggregate rating, dtype: float64
# Median of Aggregate rating is 3.2
# Std of Aggregate rating is  1.5163775396521328

# %%
d=df['Votes']
mean=d.mean()
mode=d.mode()
median=d.median()
std=d.std()
print('Mean of  Votes is ',mean)
print('Mode of Votes is ',mode)
print('Median of Votes is', median)
print('Std of Votes is ',std)
# Out:
# Mean of  Votes is  156.909747670401
# Mode of Votes is  0    0
# Name: Votes, dtype: int64
# Median of Votes is 31.0
# Std of Votes is  430.1691453762912

# %%
country_distribution=df['Country Code'].value_counts()
print("Country Distribution :",country_distribution)
# Out:
# Country Distribution : Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
city_distribution=df['City'].value_counts()
print('City Distribution :',city_distribution)
# Out:
# City Distribution : City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %%
cusine_distribution=df['Cuisines'].value_counts()
print('Cusine Distribution :',cusine_distribution)
# Out:
# Cusine Distribution : Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
#for exploring cusines
cusine_counts={}
for cusine in df['Cuisines']:
    cusine_counts[cusine]=cusine_counts.get(cusine,0)+1

# %%
cusine_counts
# Out:
# {'French, Japanese, Desserts': 1,
#  'Japanese': 17,
#  'Seafood, Asian, Filipino, Indian': 1,
#  'Japanese, Sushi': 18,
#  'Japanese, Korean': 3,
#  'Chinese': 354,
#  'Asian, European': 2,
#  'Seafood, Filipino, Asian, European': 1,
#  'European, Asian, Indian': 1,
#  'Filipino': 3,
#  'Filipino, Mexican': 2,
#  'American, Ice Cream, Desserts': 1,
#  'Korean': 6,
#  'Cafe, American, Italian, Filipino': 1,
#  'Italian, Pizza': 24,
#  'Cafe, Korean, Desserts': 1,
#  'Cafe, Bakery, American, Italian': 1,
#  'Seafood, American, Mediterranean, Japanese': 1,
#  'American, Asian, Italian, Seafood': 1,
#  'Fast Food, French': 1,
#  'Cafe': 299,
#  'Bakery': 218,
#  'Brazilian': 9,
#  'Pizza': 53,
#  'Arabian': 1,
#  'Brazilian, Cafe': 1,
#  'Italian': 54,
#  'Bar Food, Brazilian': 2,
#  'Mexican, Grill': 1,
#  'International': 6,
#  'Peruvian, Latin American': 1,
#  'American, Grill': 1,
#  'Seafood': 14,
#  'American, Burger': 13,
#  'Seafood, Bar Food, Brazilian': 1,
# ...

# %%
cusine_distribution=pd.Series(cusine_counts)

# %%
cusine_distribution=cusine_distribution.sort_values(ascending=False)

# %%
cusine_distribution
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Length: 1826, dtype: int64

# %%
cusine_distribution.head(10)
print('Top Cusines are:',cusine_distribution)
# Out:
# Top Cusines are: North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Length: 1826, dtype: int64

# %%
top_cities=city_distribution.head(10)
print('Top Cites with Highest number of Restaurents are:',top_cities)
# Out:
# Top Cites with Highest number of Restaurents are: City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
top_cities.plot(kind='bar',figsize=(10,6),color='blue')
plt.title('Top Cities with Highest Number of Restaurent ')
plt.xlabel('City')
plt.ylabel('Number of Restaurent')
plt.xticks(rotation=45)
plt.show()
