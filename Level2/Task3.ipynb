# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10688\1020607637.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r'c:\Users\Dell\Downloads\Dataset .csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
res_len=df['Restaurant Name'].apply(lambda x: len(x))
add_len=df['Address'].apply(lambda x: len(x))

# %%
res_len
# Out:
# 0       16
# 1       16
# 2       22
# 3        4
# 4       11
#         ..
# 9546    11
# 9547    12
# 9548     5
# 9549    11
# 9550    24
# Name: Restaurant Name, Length: 9551, dtype: int64

# %%
add_len
# Out:
# 0        71
# 1        67
# 2        56
# 3        70
# 4        64
#        ...
# 9546    103
# 9547     77
# 9548     73
# 9549     75
# 9550     65
# Name: Address, Length: 9551, dtype: int64

# %%
#df['Has Table booking']=pd.get_dummies(df['Has Table booking'],drop_first=True)
#df['Has Online delivery']=pd.get_dummies(df['Has Online delivery'],drop_first=True)

# %%
x=pd.get_dummies(df['Has Table booking'],drop_first=True)

# %%
y=pd.get_dummies(df['Has Online delivery'],drop_first=True)

# %%
x
# Out:
#         Yes
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# ...     ...
# 9546  False
# 9547  False
# 9548  False
# 9549  False
# 9550  False
#
# [9551 rows x 1 columns]

# %%
y
# Out:
#         Yes
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9546  False
# 9547  False
# 9548  False
# 9549  False
# 9550  False
#
# [9551 rows x 1 columns]
